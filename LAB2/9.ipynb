# %% [markdown]
# ## Ćwiczenie 9

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tifffile

def average_filter(image_path, kernel_size):
    img = tifffile.imread(image_path)
    img = np.clip(img, 0, 255).astype(np.uint8)

    # Apply average (mean) filter
    kernel = np.ones((kernel_size, kernel_size), np.float32) / (kernel_size * kernel_size)
    filtered_img = cv2.filter2D(img, -1, kernel)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Obraz przed filtracją')
    axes[0].axis('off')

    axes[1].imshow(filtered_img, cmap='gray')
    axes[1].set_title('Obraz po użyciu filtra uśredniającego')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()


    return filtered_img


image_path = 'pliki/cboard_pepper_only.tif'
average_filter(image_path, 3)
# Out:
# array([[248, 220, 220, ..., 220, 247, 247],
#        [248, 220, 220, ..., 192, 192, 220],
#        [248, 248, 220, ..., 220, 192, 220],
#        ...,
#        [180, 180, 155, ..., 137, 160, 168],
#        [232, 232, 206, ..., 153, 160, 169],
#        [232, 232, 232, ..., 152, 160, 169]], dtype=uint8)

# %%
def min_filter(image_path, kernel_size=3):
    img = tifffile.imread(image_path)
    img = np.clip(img, 0, 255).astype(np.uint8)

    # Apply minimum filter using erosion
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    filtered_img = cv2.erode(img, kernel)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Obraz przed filtracją')
    axes[0].axis('off')

    axes[1].imshow(filtered_img, cmap='gray')
    axes[1].set_title('Obraz po użyciu filtra minimum')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

    return filtered_img


min_filter(image_path, 3)
# Out:
# array([[248,   0,   0, ...,   0, 247, 247],
#        [248,   0,   0, ...,   0,   0,   0],
#        [248, 248,   0, ...,   0,   0,   0],
#        ...,
#        [  0,   0,   0, ...,   0, 142, 167],
#        [232, 232,   0, ..., 141, 141, 168],
#        [232, 232, 232, ..., 141, 141, 168]], dtype=uint8)

# %%
def max_filter(image_path, kernel_size=3):
    img = tifffile.imread(image_path)
    img = np.clip(img, 0, 255).astype(np.uint8)

    # Apply maximum filter using dilation
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    filtered_img = cv2.dilate(img, kernel)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Obraz przed filtracją')
    axes[0].axis('off')

    axes[1].imshow(filtered_img, cmap='gray')
    axes[1].set_title('Obraz po użyciu filtra maximum')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

    return filtered_img


max_filter(image_path, 3)
# Out:
# array([[248, 248, 248, ..., 248, 248, 248],
#        [248, 248, 248, ..., 248, 248, 248],
#        [248, 248, 248, ..., 248, 248, 248],
#        ...,
#        [232, 232, 232, ..., 168, 170, 170],
#        [232, 232, 232, ..., 168, 171, 171],
#        [232, 232, 232, ..., 168, 171, 171]], dtype=uint8)
